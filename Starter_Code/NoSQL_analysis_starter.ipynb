# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene":20}

# Use count_documents to display the number of documents in the result
docs= db.establishments.count_documents(query)
results = establishments.find(query)
print("number of establishments with Hygene score =20: ", docs)
# Display the first document in the results using pprint
print("first document in the results")
pprint(results[0])
# Out:
# number of establishments with Hygene score =20:  41
# first document in the results
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646a7110547e86180d2732e2'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
# ...

# %%
# Convert the result to a Pandas DataFrame
result_df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(result_df))
# Display the first 10 rows of the DataFrame
result_df.head(10)
# Out:
# Rows in DataFrame:  41
#                         _id   FHRSID  ChangesByServerID  \
# 0  646a7110547e86180d2732e2   110681                  0
# 1  646a7110547e86180d273663   612039                  0
# 2  646a7111547e86180d27396d   730933                  0
# 3  646a7111547e86180d273b5b   172735                  0
# 4  646a7111547e86180d273b6a   172953                  0
# 5  646a7112547e86180d274509   512854                  0
# 6  646a7112547e86180d27472a  1537089                  0
# 7  646a7115547e86180d275c55   155648                  0
# 8  646a7115547e86180d276099  1012883                  0
# 9  646a7116547e86180d2768ab   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.

query = {"RatingValue":{'$gte': 4},'LocalAuthorityName': {"$regex": "London" }}

# Use count_documents to display the number of documents in the result
docs= db.establishments.count_documents(query)
results_ratings = establishments.find(query)
print("number of establishments with RatingValue greater than or equal to 4: ", docs)
# Display the first document in the results using pprint
print("first document in the results")
pprint(results_ratings[0])
# Out:
# number of establishments with RatingValue greater than or equal to 4:  33
# first document in the results
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646a7113547e86180d274cfd'),
# ...

# %%
# Convert the result to a Pandas DataFrame
result_ratings_df = pd.DataFrame(results_ratings)
# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(result_ratings_df))
# Display the first 10 rows of the DataFrame
result_ratings_df.head(10)
# Out:
# Rows in DataFrame:  33
#                         _id   FHRSID  ChangesByServerID  \
# 0  646a7113547e86180d274cfd   621707                  0
# 1  646a7113547e86180d275023  1130836                  0
# 2  646a7115547e86180d275b70   293783                  0
# 3  646a7116547e86180d276970  1315095                  0
# 4  646a7116547e86180d276971   294474                  0
# 5  646a7117547e86180d277079   294900                  0
# 6  646a711a547e86180d279187   293756                  0
# 7  646a711b547e86180d27954e   878523                  0
# 8  646a711b547e86180d279568   293772                  0
# 9  646a711b547e86180d279569   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000

query = {"RatingValue": 5,
        '$and':[{'geocode.latitude':{'$gt':latitude-degree_search}},{'geocode.latitude':{'$lt':latitude+degree_search}}],
         '$and':[{'geocode.longitude':{'$gt':longitude-degree_search}},{'geocode.longitude':{'$lt':longitude+degree_search}}]
        }
         
docs= db.establishments.count_documents(query)

results_radius = establishments.find(query).sort("scores.Hygiene").limit(5)
print("number of establishments with RatingValue equal to 5: ", docs)
# Display the first document in the results using pprint
print("first document in the results")
pprint(results_radius[0])
# Out:
# number of establishments with RatingValue equal to 5:  862
# first document in the results
# {'AddressLine1': 'Unit 18',
#  'AddressLine2': 'Staple Tye Shopping Centre',
#  'AddressLine3': 'Southern Way',
#  'AddressLine4': 'Harlow',
#  'BusinessName': 'The Food Shop',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4656.729830240595,
#  'FHRSID': 1387399,
#  'LocalAuthorityBusinessID': 'COMM/21/00087',
#  'LocalAuthorityCode': '116',
#  'LocalAuthorityEmailAddress': 'env.health@harlow.gov.uk',
#  'LocalAuthorityName': 'Harlow',
#  'LocalAuthorityWebSite': 'http://www.harlow.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CM18 7PJ',
#  'RatingDate': '2021-10-07T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('646a711d547e86180d27ab56'),
#  'geocode': {'latitude': 51.753186, 'longitude': 0.091959},
# ...

# %%
# Convert result to Pandas DataFrame

result_radius_df = pd.DataFrame(results_radius)
# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(result_radius_df))
# Display the the DataFrame
result_radius_df
# Out:
# Rows in DataFrame:  5
#                         _id   FHRSID  ChangesByServerID  \
# 0  646a711d547e86180d27ab56  1387399                  0
# 1  646a7111547e86180d273d0f   174047                  0
# 2  646a7111547e86180d273d16   173610                  0
# 3  646a7111547e86180d273d9a   173738                  0
# 4  646a7111547e86180d273cbe   174020                  0
#
#   LocalAuthorityBusinessID                        BusinessName  \
# 0            COMM/21/00087                       The Food Shop
# 1             PI/000027871  Clifden House Dementia Care Centre
# 2             PI/000026322                Beachlands Care Home
# 3             PI/000026802                        Ab Fab Rooms
# 4             PI/000027807                   Angies Newsagents
#
#                         BusinessType  BusinessTypeID          AddressLine1  \
# 0             Takeaway/sandwich shop            7844               Unit 18
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
match_query = {'$match': {"scores.Hygiene":0}}

# 2. Groups the matches by Local Authority
group_query = {'$group': {'_id': '$LocalAuthorityName', 'count': { '$sum': 1 }}}


# 3. Sorts the matches from highest to lowest
sort_values = {'$sort': { 'count': -1 }}

# Print the number of documents in the result
pipeline = [match_query, group_query, sort_values]
results = list(establishments.aggregate(pipeline))
print("Number of local authorities with hygiene score of 0:  ", len(results))

# Print the first 10 results
pprint(results[0:10])
# Out:
# Number of local authorities with hygiene score of 0:   55
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame
result_df = pd.DataFrame(results)

print("Rows in DataFrame: ", len(result_df))
result_df.head(10)
# Out:
# Rows in DataFrame:  55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
